# %%
import cv2
import numpy as np
# from svgwrite import Drawing, rgb
from cv2 import aruco
import matplotlib.pyplot as plt

# %%
size = 200
aruco_dict = aruco.getPredefinedDictionary(aruco.DICT_APRILTAG_36H11)

# %%
id = 4

aruco_dict.generateImageMarker(id, 190).shape
# plt.imshow(aruco_dict.generateImageMarker(id, 190), cmap='gray')
# Your plot code
fig, ax = plt.subplots()

# Plot some example data
ax.imshow(aruco_dict.generateImageMarker(id, 190), cmap='gray')

# Remove the axes and ticks
ax.set_axis_off()

# Save the figure without borders
# plt.savefig('ID_8.png', bbox_inches='tight', pad_inches=0)

# Show the plot (optional)
plt.show()
